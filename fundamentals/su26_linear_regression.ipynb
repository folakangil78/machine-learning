# %% [markdown]
# # Introduction to Linear Regression
#
# *Adapted from Chapter 3 of [An Introduction to Statistical Learning](https://www.statlearning.com/)*
#
# Will be using [Pandas](https://pandas.pydata.org/docs/user_guide/10min.html) and [scikit-learn](http://scikit-learn.org/stable/).
#
# Instructions:
#
#
# *   Questions are marked by the sign ⏩. Provide the answer after the question, either in a code cell or in a text cell (or both).
# *   Upload the notebook on the website of the course. Direct emails will be ignored. -- Deadline : one week after the day of the lab.
# * Your notebook is an individual work.

# %%
# imports
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy import stats

# this allows plots to appear directly in the notebook
# %matplotlib inline

# %% [markdown]
# ## I. The Dataset
#
# Let's take a look at some data, ask some questions about that data, and then use linear regression to answer those questions!

# %%
# read data into a DataFrame
data = pd.read_csv('https://raw.githubusercontent.com/justmarkham/scikit-learn-videos/master/data/Advertising.csv', index_col=0)

# %% [markdown]
# ⏩ **1) Use `data.head()` and `data.head(10)`: describe the dataset.**

# %%
data.head()
data.head(10)
# difference between lines is returning first five lines versus first ten lines (which has to be specified)
# Out:
#        TV  Radio  Newspaper  Sales
# 1   230.1   37.8       69.2   22.1
# 2    44.5   39.3       45.1   10.4
# 3    17.2   45.9       69.3    9.3
# 4   151.5   41.3       58.5   18.5
# 5   180.8   10.8       58.4   12.9
# 6     8.7   48.9       75.0    7.2
# 7    57.5   32.8       23.5   11.8
# 8   120.2   19.6       11.6   13.2
# 9     8.6    2.1        1.0    4.8
# 10  199.8    2.6       21.2   10.6

# %% [markdown]
# What are the features?
# - TV: advertising dollars spent on TV for a single product in a given market (in thousands of dollars)
# - Radio: advertising dollars spent on Radio
# - Newspaper: advertising dollars spent on Newspaper
#
# What is the response?
# - Sales: sales of a single product in a given market (in thousands of widgets)
#
# ⏩ **2) Use data.shape. How many examples are contained in the dataset?**
#
# ⏩ **3) Use data.describe() and provide your comments.**

# %%
data.shape # 200
data.describe()
# shape provides number of rows and columns
# describe provides summary stats for each column.
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   14.022500
# std     85.854236   14.846809   21.778621    5.217457
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   10.375000
# 50%    149.750000   22.900000   25.750000   12.900000
# 75%    218.825000   36.525000   45.100000   17.400000
# max    296.400000   49.600000  114.000000   27.000000

# %% [markdown]
# ⏩ **4) Use data['Name_column'].hist() to draw the histogram of the sales. Set the parameters in order to plot 20 bins (= bars of the histogram. On the histogram, locate the 25% quantile given by the describe() method of the previous question.**

# %%
# draw histogram of Sales with 20 bins
data['Sales'].hist(bins=20)

# from describe() the 25% quantile of Sales is ~10.375 — drop a vertical line at that x-value to locate it
plt.axvline(x=data['Sales'].quantile(0.25), color='red', linestyle='--', label='25% quantile')

# labels + legend so the chart is readable
plt.xlabel('Sales (thousands of widgets)')
plt.ylabel('Frequency')
plt.title('Histogram of Sales')
plt.legend()
plt.show()

# %% [markdown]
# ⏩ **5) Comment the result of data.boxplot(). What is the interest of this plot?**

# %%
# boxplot of every numeric column in the dataframe
data.boxplot()
plt.title('Boxplot of all features and the response')
plt.show()

# Interest of this plot: for each column it visually summarises the median, interquartile range,
# whiskers, and outliers — so I get the spread, skew, and the presence of extreme values for
# every variable:
# - TV has the widest spread (roughly 0 to 300) and a roughly symmetric box
# - Newspaper has a clearly visible right tail with high-end outliers
# - Radio is more compact and bounded
# - Sales sits in a narrower range with no extreme outliers

# %% [markdown]
# ⏩ **5) Use data.plot(kind='scatter', x=..., y=...) to vizualize the relationship between the features and the response. Comment about the relevance of the use of a linear model.**

# %%
# 3 scatter plots side by side, one per feature vs Sales
fig, axes = plt.subplots(1, 3, figsize=(15, 4))

# TV vs Sales — clear positive, roughly linear trend
data.plot(kind='scatter', x='TV', y='Sales', ax=axes[0])

# Radio vs Sales — positive trend, but noisier
data.plot(kind='scatter', x='Radio', y='Sales', ax=axes[1])

# Newspaper vs Sales — relationship looks weak / fairly diffuse
data.plot(kind='scatter', x='Newspaper', y='Sales', ax=axes[2])

plt.show()

# Relevance of a linear model:
# TV in particular shows a fairly linear positive relationship with Sales, so a linear model is
# a reasonable first try. Radio also shows some linearity, though with more scatter at high
# spend. Newspaper looks much weaker — a linear model on Newspaper alone would not be very useful.
# Overall a linear model is a sensible baseline, especially when we eventually combine all features.

# %% [markdown]
# ⏩ **6) Use data.corr() in order to plot the correlation coefficients.**
#
# **Comment about the coefficient on the diagonal.**
#
# **What feature is the most correlated to the sales?**
#
# **Plot the correlation matrix as a heatmap using sns.heatmap(...,annot=True)**

# %%
# correlation matrix between every pair of columns
corr = data.corr()
print(corr)

# the diagonal is always 1 — that's the correlation of each variable with itself, which is by
# definition perfect. It carries no information about the data; it's just a property of corr().

# whichever feature has the largest absolute correlation with Sales is the most predictive on its own
print('Most correlated with Sales:', corr['Sales'].drop('Sales').abs().idxmax())

# heatmap with the numeric values annotated in each cell for readability
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Correlation heatmap')
plt.show()
# Out:
#                  TV     Radio  Newspaper     Sales
# TV         1.000000  0.054809   0.056648  0.782224
# Radio      0.054809  1.000000   0.354104  0.576223
# Newspaper  0.056648  0.354104   1.000000  0.228299
# Sales      0.782224  0.576223   0.228299  1.000000
# Most correlated with Sales: TV

# %% [markdown]
# ### Questions About the Advertising Data
#
# Let's pretend you work for the company that manufactures and markets this widget. The company might ask you the following: On the basis of this data, how should we spend our advertising money in the future?
#
# This general question might lead you to more specific questions:
# 1. Is there a relationship between ads and sales?
# 2. How strong is that relationship?
# 3. Which ad types contribute to sales?
# 4. What is the effect of each ad type of sales?
# 5. Given ad spending in a particular market, can sales be predicted?
#
# We will explore these questions below!

# %% [markdown]
# ## II. Simple Linear Regression
#
# Simple linear regression is an approach for predicting a **quantitative response** using a **single feature** (or "predictor" or "input variable"). It takes the following form:
#
# $y = \beta_0 + \beta_1x$
#
# What does each term represent?
# - $y$ is the response
# - $x$ is the feature
# - $\beta_0$ is the intercept
# - $\beta_1$ is the coefficient for x
#
# Together, $\beta_0$ and $\beta_1$ are called the **model coefficients**. To create your model, you must "learn" the values of these coefficients. And once we've learned these coefficients, we can use the model to predict Sales!
#
# Generally speaking, coefficients are estimated using the **least squares criterion**, which means we are find the line (mathematically) which minimizes the **sum of squared residuals** (or "sum of squared errors"):
# ![image.png](data:image/png;base64,...)
#
# What elements are present in the diagram?
# - The black dots are the **observed values** of x and y.
# - The blue line is our **least squares line**.
# - The red lines are the **residuals**, which are the distances between the observed values and the least squares line.
#
# How do the model coefficients relate to the least squares line?
# - $\beta_0$ is the **intercept** (the value of $y$ when $x$=0)
# - $\beta_1$ is the **slope** (the change in $y$ divided by change in $x$)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ⏩ **7) We are going to do linear regression of the sales with respect to ONE variable amongst 'TV', 'Radio', 'Newspaper'. According to what you have seen from the dataset, which column would you like to keep? Write it down under the form:**
#
# `columns = ['Name of the column you want to keep']`

# %%
# from the scatter plots and the correlation matrix, TV had the strongest linear relationship
# with Sales (highest absolute correlation, cleanest scatter). So TV is the feature I'll keep for
# the simple (one-variable) linear regression in the next questions.
columns = ['TV']

# %% [markdown]
# ⏩ **8) Run the code below and try to understand it. What are the value of $\beta_0$ and $\beta_1$ of you model?**

# %%
# import sklearn's ordinary-least-squares linear regression class
from sklearn.linear_model import LinearRegression

# instantiate the model — no fitting has happened yet
ls = LinearRegression()

# fit the model on TV (X) against Sales (y); under the hood this solves the normal equations
ls.fit(data[columns], data['Sales'])

# .intercept_ is beta_0, .coef_[0] is beta_1 (only one feature so coef_ has length 1)
ls.intercept_, ls.coef_[0]
# Running this prints roughly (7.0326, 0.0475) — so beta_0 ~ 7.03 and beta_1 ~ 0.0475.
# Out:
# (np.float64(7.0325935491276885), np.float64(0.04753664043301979))

# %% [markdown]
# How do we interpret the TV coefficient ($\beta_1$)?
# - A "unit" increase in TV ad spending is associated with a 0.047537 "unit" increase in Sales.
# - Or more clearly: An additional $1,000 spent on TV ads is associated with an increase in sales of 47.537 widgets.
#
# Note that if an increase in TV ad spending was associated with a decrease in sales, $\beta_1$ would be negative.
#
# ⏩ **9) Let's say that there was a new market where the spend in the advertising channel you considered was $50,000. What would we predict for the Sales in that market? Make the prediction "by hand" using sums and multiplication of numbers.**

# %%
# manually calculate the prediction
# the dataset measures TV ad spending in thousands of dollars, so $50,000 corresponds to x = 50
# our model is y_hat = beta_0 + beta_1 * x
beta_0 = ls.intercept_
beta_1 = ls.coef_[0]
x = 50  # 50 thousand dollars of TV ad spending

# perform the linear combination by hand using a sum and a multiplication
y_hat = beta_0 + beta_1 * x
print('Predicted Sales (thousands of widgets):', y_hat)
# Out:
# Predicted Sales (thousands of widgets): 9.409425570778678

# %% [markdown]
# ⏩ **10) Use sklearn's predict method to recover the above result:**
#
#
#
# ```
# New_data = pd.DataFrame({'Name of your column' : [the value]})
# ls.predict(New_data)[0]
# ```

# %%
# build a one-row DataFrame with the same column name(s) the model was trained on
New_data = pd.DataFrame({'TV': [50]})

# .predict returns an array of predictions, [0] grabs the first (and only) one
prediction = ls.predict(New_data)[0]
print('sklearn predicted Sales:', prediction)

# this should match the manual calculation from the previous cell
# Out:
# sklearn predicted Sales: 9.409425570778678

# %% [markdown]
# ⏩ **11) Using `ls.predict`, generate the predictions $\hat y_i$ for the whole dataset. On the same graph, plot the scattered points $(x_i,y_i)$ and the line passing through the points $(x_i,\hat y_i)$.**

# %%
# generate predictions y_hat_i for every row of the dataset
y_hat = ls.predict(data[columns])

# scatter the real data points (x_i, y_i)
plt.scatter(data['TV'], data['Sales'], label='actual', alpha=0.6)

# plot the regression line by connecting the predicted points (x_i, y_hat_i).
# sort by TV first so matplotlib draws the line smoothly left-to-right rather than zig-zagging
sort_idx = data['TV'].argsort()
plt.plot(data['TV'].values[sort_idx], y_hat[sort_idx], color='red', label='fitted line')

plt.xlabel('TV ad spending (thousands of dollars)')
plt.ylabel('Sales (thousands of widgets)')
plt.title('Simple linear regression: Sales vs TV')
plt.legend()
plt.show()

# %% [markdown]
# ⏩ **12) Write your comments. How happy are you with the model?**

# %% [markdown]
# **Comments of model**
#
# The fit captures the overall positive trend between TV ad spending and Sales — there *is* a relationship, and a linear one is a reasonable first approximation. However the model isn't perfect:
#
# - The scatter of real points around the regression line is wide, especially at higher TV spend, suggesting the variance of Sales given TV is not constant (mild heteroskedasticity).
# - A single-feature model ignores Radio and Newspaper entirely, even though Radio in particular has a non-trivial correlation with Sales.
# - Visually the residuals look roughly symmetric around the line, but there's a pretty noticeable spread — so point predictions can be off by several thousand widgets.
#
# I guess I'm **moderately happy** with the model. It's a decent baseline, but a multivariate model that adds Radio (and possibly Newspaper) would probably fit better.

# %% [markdown]
# ## III. Multiple Linear Regression
#
# Simple linear regression can easily be extended to include multiple features. This is called **multiple linear regression**:
#
# $y = \beta_0 + \beta_1x_1 + ... + \beta_nx_n$
#
# Each $x$ represents a different feature, and each feature has its own coefficient. In this case:
#
# $y = \beta_0 + \beta_1 \times TV + \beta_2 \times Radio + \beta_3 \times Newspaper$
#
# ⏩ **13) Include all the three columns in the model and re-train a least-square estimator using scikit-learn. Provide the values of the coefficients $\beta_i$.**

# %%
# now use all three advertising channels as features
columns_all = ['TV', 'Radio', 'Newspaper']

# fit a new least-squares linear regressor on the full feature set
ls_multi = LinearRegression()
ls_multi.fit(data[columns_all], data['Sales'])

# beta_0 is the intercept; beta_1, beta_2, beta_3 are the per-feature coefficients
print('beta_0 (intercept):', ls_multi.intercept_)
for name, beta in zip(columns_all, ls_multi.coef_):
    print(f'beta for {name}: {beta}')
# Out:
# beta_0 (intercept): 2.938889369459403
# beta for TV: 0.04576464545539764
# beta for Radio: 0.18853001691820453
# beta for Newspaper: -0.001037493042476269

# %% [markdown]
# ⏩ **14) For a given amount of Radio and Newspaper ad spending, how much is the increase of sells resulting from a $1000 increase in TV ad spending?**

# %% [markdown]
# **Answer.**
#
# Holding Radio and Newspaper spending fixed, an increase of \$1{,}000 in TV ad spending corresponds to one additional "unit" of TV in the dataset (since the units are thousands of dollars). The associated increase in Sales is therefore exactly the TV coefficient $\beta_{\text{TV}}$ from the multiple regression above.
#
# From the fit, $\beta_{\text{TV}} \approx 0.0458$, so a \$1{,}000 increase in TV spending — with Radio and Newspaper held constant — is associated with an increase of about **0.0458 thousand widgets ≈ 45.8 additional widgets** sold.

# %% [markdown]
# ### Linear Gaussian model and confidence intervals
#
# Up to now, we have treated linear regression as a deterministic optimization problem: given a dataset $(x_1, y_1),  \ldots, (x_n, y_n)$, we computed coefficients $\hat{\boldsymbol{\beta}} = (\hat\beta_0, \hat \beta_1​, \hat\beta_2, \hat\beta_3)$ that minimize a least-squares error.
#
# In this section, we take one additional step and introduce a probabilistic model for the data. This will allow us to quantify uncertainty in the estimated coefficients.
# The key idea is the following: even if the regression model is linear, the observed data may vary due to measurement errors, unobserved factors, or model mismatch. To account for this variability, we assume that the observations are generated according to a linear Gaussian model. Therefore, there exists some parameters $\boldsymbol{\beta}^\star = (\beta^\star_0, \beta^\star_1​, \beta^\star_2, \beta^\star_3)$ such that each label $y_i$ is connected to its features $x_i$ as follows:
# $$
#   y_i = x_i^\top \beta^\star + \varepsilon_i \enspace,
# $$
# and $\varepsilon_i$ is some Gaussian noise of variance $\sigma^2$, that is $\varepsilon_i \sim \mathcal{N}(0, \sigma^2)$. Keep in mind that both $\beta^\star$ and $\sigma^2$ are unknown. The noise variable is here to model the imperfection of the measurements, or the fact that sometimes the linear model is not a perfect representation of the underlying phenomenon.
#
# Under this assumption, the least-squares estimator $\hat\beta$ is not only an optimizer, but also a **random variable**. Confidence intervals provide a way to describe how much $\hat\beta$ may vary due to the randomness in the labels.
#
# A 95% confidence interval on $\beta_k$ is given by:
# $$
# \hat\beta_k \pm q_k \sqrt{\frac {\hat\sigma^2}N}
# $$
# where $\hat \sigma^2$ is the estimated variance (since we do not know $\sigma^2$!), given by:
# $$
# \hat \sigma^2 = \frac{1}{N-d-1} \sum_{i = 1}^N (y_i - \hat{y}_i)^2 \enspace.
# $$
# The parameter $q_k$ depends on the level of confidence of our interval, as well as the features used for the regression.
#
# A 95% confidence interval for a coefficient $\beta_k$ can be interpreted as follows: if we were able to repeat the data collection process a hundred times under the same model assumptions, find the associated optimized $\hat\beta$ and compute a confidence interval around that $\hat\beta$, then approximately 95% of the resulting confidence intervals would contain the true value of $\beta^\star$.
#
# Note that using 95% confidence intervals is just a convention. You can create 90% confidence intervals (which will be more narrow), 99% confidence intervals (which will be wider), or whatever intervals you like.

# %% [markdown]
# ⏩ **15) Draw the histogram of the residuals $e_i=\hat y_i-y_i$, using 20 bins.**
#
# **Without calculating it numerically, what is APPROXIMATELY the mean and the standard deviation?**
#
# **Does it make sense to assume that the residuals are Gaussian?**

# %% [markdown]
# The following function computes confidence intervals. The syntax is as follows:
#
#
# ```
# confidence_interval(X,y,a,k)
# ```
#
# where `X` is a $N\times d$ pandas dataframe corresponding to the design matrix, `y` is a pandas series corresponding to the labels, $a$ is the confidence level between 0 and 1 (typically set to 0.95), and $k\in\{0,1,\dots,d\}$ represents the variable you would like to consider.
#
# ⏩ **16) Compute the confidence intervals for the 3 variables.**

# %%
def confidence_interval(X,y,a,k):
  assert(a<1)
  (N,d) = X.shape
  lsf = LinearRegression()
  lsf.fit(X,y)
  variance = np.linalg.norm(y.values-lsf.predict(X))**2/(N-d-1)
  Phi = np.concatenate((np.reshape(np.ones(N),(N,1)),X.to_numpy()),axis=1)
  s = np.diag(np.linalg.inv(np.dot(Phi.T,Phi)))[k]
  q = stats.t(df=N-d-1).ppf(1-(1-a)/2)
  return (lsf.coef_[k-1]-q*np.sqrt(variance*s/N),lsf.coef_[k-1]+q*np.sqrt(variance*s/N))

# %% [markdown]
# ⏩ **17) Compute confidence intervals at 99%. Based on this result, if you wanted to eliminate one feature from the model, which one would it be? Explain.**

# %% [markdown]
# ## IV. Model selection by cross-validation
#
# Consider we seek to choose between two models:
#
#
# *   The first one includes all the columns `TV`, `Radio`, `Newspaper`
# *   The second one includes only `TV` and `Radio`
#
# Which one should one choose?
#
# **Cross-validation.** provides a reliable estimate of out-of-sample error, and thus is a better way to choose which of your models will best **generalize** to out-of-sample data. There is extensive functionality for cross-validation in scikit-learn, including automated methods for searching different sets of parameters and different models. Importantly, cross-validation can be applied to any model, whereas the methods described above only apply to linear models.

# %% [markdown]
# **⏩** **18) Use sklearn `train_test_split` method to spli the data into a train and a test set (see the doc [here](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html)). Then, fit two linear regressors on the train set only: one using all features, the other using only `TV` and`Radio`.**

# %%
# import the helper that randomly splits data into a train and a test partition
from sklearn.model_selection import train_test_split

# features and target. X_full has all three advertising channels, y is always Sales
X_full = data[['TV', 'Radio', 'Newspaper']]
y = data['Sales']

# 70/30 train/test split. random_state is intentionally left unset so different re-runs produce
# different splits — that's exactly what Deliverable 20 asks us to observe.
X_train, X_test, y_train, y_test = train_test_split(X_full, y, test_size=0.3)

# model A: uses all three features
ls_all = LinearRegression().fit(X_train, y_train)

# model B: uses only TV and Radio — slice the same train rows so the comparison stays fair
ls_tv_radio = LinearRegression().fit(X_train[['TV', 'Radio']], y_train)

# quick sanity print of the fitted coefficients
print('Full-model coefs   :', dict(zip(X_full.columns, ls_all.coef_)))
print('TV+Radio model coefs:', dict(zip(['TV', 'Radio'], ls_tv_radio.coef_)))
# Out:
# Full-model coefs   : {'TV': np.float64(0.04426731984001265), 'Radio': np.float64(0.19306582192708388), 'Newspaper': np.float64(-0.00463498448490448)}
# TV+Radio model coefs: {'TV': np.float64(0.0442753738036871), 'Radio': np.float64(0.19049912274444314)}

# %% [markdown]
# ⏩ **19) Use sklearn `mean_squared_error` (doc [here](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.mean_squared_error.html)) to compare the mean squared error of both models, on the test set.**

# %%
from sklearn.metrics import mean_squared_error

# predict on the held-out test set with each model
y_pred_all = ls_all.predict(X_test)
y_pred_tv_radio = ls_tv_radio.predict(X_test[['TV', 'Radio']])

# MSE = average squared residual on the test set — lower is better
mse_all = mean_squared_error(y_test, y_pred_all)
mse_tv_radio = mean_squared_error(y_test, y_pred_tv_radio)

print('Test MSE (TV + Radio + Newspaper):', mse_all)
print('Test MSE (TV + Radio)            :', mse_tv_radio)
# Out:
# Test MSE (TV + Radio + Newspaper): 3.273143542038419
# Test MSE (TV + Radio)            : 3.230584198784681

# %% [markdown]
# ⏩ **20) Observe that the mean square error vary, when you re-run the cells corresponding to Questions 21 and 22. How do you explain this?**
#
# ⏩ **21) Between the two models, which one would you recommend? Justify.**
#
# ⏩ **22) To choose between two models, your method seems to depend on the ratio of the test set versus the train set. Can you see a more rigorous method allowing to cross-validate the model?**

# %% [markdown]
# **20) Why does the MSE vary on re-runs?**
#
# `train_test_split` shuffles the rows differently on every call because we did not fix `random_state`. A different test set means different "easy" or "hard" examples end up being scored, so the test MSE jumps around. With only 200 rows total and ~60 in each test set, this sampling noise is substantial — a single split is a noisy estimator of true generalization error.
#
# **21) Which model would you recommend?**
#
# Across repeated re-runs the two models perform very similarly, and the **TV + Radio** model is typically as good as — or sometimes better than — the full three-feature model. That matches what we saw earlier: Newspaper's coefficient is small and its correlation with Sales is weak, so including it tends to *fit noise* on the training set without reducing test error. By parsimony (Occam's razor), I'd recommend the simpler **TV + Radio** model: fewer parameters, similar (or better) out-of-sample performance, and easier to interpret.
#
# **22) A more rigorous comparison method**
#
# A single train/test split gives a noisy answer that depends on the lucky/unlucky choice of split. The standard fix is some form of **cross-validation**: partition the data into a number of roughly equal folds, train on $n-1$ folds, evaluate on the held-out fold, and repeat so every row appears in the test set exactly once. Average the MSEs to get a much more stable estimate of generalization error (and the standard deviation across folds tells you how reliable that estimate is). So something like (cross val score from sklearn):
#
# ```python
# cross_val_score(model, X, y, cv=k, scoring='neg_mean_squared_error')
# ```
#
# Repeated n-fold (or leave-one-out since this dataset is small $N = 200$) further reduces the dependence on any single partition.

# %% [markdown]
# ## Resources
#
# - To go much more in-depth on linear regression, read Chapter 3 of [An Introduction to Statistical Learning](https://www.statlearning.com/), from which this lesson was adapted. Alternatively, watch the [related videos](http://www.dataschool.io/15-hours-of-expert-machine-learning-videos/) or read [quick reference guide](http://www.dataschool.io/applying-and-interpreting-linear-regression/) to the key points in that chapter.
